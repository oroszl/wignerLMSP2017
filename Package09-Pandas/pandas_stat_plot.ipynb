# %% [markdown]
# # Statisztikák és ábrázolásuk (seaborn)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %% [markdown]
# # Érettségi adatok feldolgozása

# %% [markdown]
# Az alábbiakban folytatjuk az érettségi statisztikák elemzését. Koncentrálva a statisztikai mennyiségek számítására és összefoglaló ábrák készítésére. Olvassuk be újra az adatokat:

# %%
df=pd.read_csv("data/erettsegi.csv.gz",sep=";",index_col=0)

# %% [markdown]
# # Elemi statisztika
#
# A describe függvény segítségével kaphatunk egy összefoglalót a táblázatunkról.

# %%
df.describe()
# Out:
#        vizsgázó évfolyama     érdemjegy  össz százalék  össz pontszám  \
# count        19811.000000  21444.000000   21444.000000   21444.000000
# mean            12.737015      4.022617      66.553861     100.219269
# std             34.817782      1.074826      19.247675      28.865995
# min              1.000000      1.000000       0.000000       0.000000
# 25%             12.000000      3.000000      54.000000      82.000000
# 50%             12.000000      4.000000      70.000000     105.000000
# 75%             12.000000      5.000000      82.000000     123.000000
# max           2014.000000      5.000000     100.000000     150.000000
#
#        I. feleletválasztós kérdéssor  II. esszé: tartalom  \
# count                   20635.000000          5047.000000
# mean                       22.418173            12.948286
# std                         7.112939             3.860824
# min                         2.000000             0.000000
# 25%                        18.000000            11.000000
# 50%                        22.000000            14.000000
# 75%                        28.000000            16.000000
# max                        40.000000            18.000000
#
#        II. esszé:  kifejtés módja  III. összetett feladatok  \
# count                 5047.000000               5047.000000
# mean                     4.228849                 28.152170
# std                      1.023183                 12.347646
# min                      0.000000                  0.000000
# 25%                      4.000000                 19.000000
# 50%                      5.000000                 29.000000
# 75%                      5.000000                 39.000000
# max                      5.000000                 47.000000
#
#        írásbeli pontszám  mérés és tételkifejtés: tartalmi helyesség  \
# count       20635.000000                                 5058.000000
# mean           55.282966                                   35.715896
# std            18.886694                                    9.203527
# min             8.000000                                    0.000000
# 25%            41.000000                                   31.000000
# 50%            56.000000                                   38.000000
# 75%            70.000000                                   43.000000
# max           100.000000                                   90.000000
#
#        mérés és tételkifejtés: felépítés, kifejtés  szóbeli pontszám  \
# count                                  5058.000000      20715.000000
# mean                                      4.014433         47.302872
# std                                       1.096126         12.863038
# min                                       0.000000          0.000000
# 25%                                       3.000000         40.000000
# 50%                                       4.000000         50.000000
# 75%                                       5.000000         58.000000
# max                                      10.000000        120.000000
#
#                  év  egy téma kifejtése kísérlettel vagy méréssel: tartalom  \
# count  21890.000000                                       15657.000000
# mean    2013.364824                                          45.667369
# std        1.157214                                          11.646716
# min     2011.000000                                           0.000000
# 25%     2012.000000                                          40.000000
# 50%     2013.000000                                          50.000000
# 75%     2014.000000                                          55.000000
# max     2015.000000                                         110.000000
#
#        egy téma kifejtése kísérlettel vagy méréssel: felépítés, kifejtés  \
# count                                       15657.000000
# mean                                            4.162866
# std                                             1.100549
# min                                             0.000000
# 25%                                             3.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                            10.000000
#
#        II. összetett feladatok
# count             15588.000000
# mean                 28.829099
# std                  12.855951
# min                   0.000000
# 25%                  19.000000
# 50%                  29.000000
# 75%                  40.000000
# max                  50.000000

# %%
df.describe().T
# Out:
#                                                     count         mean  \
# vizsgázó évfolyama                                  19811    12.737015
# érdemjegy                                           21444     4.022617
# össz százalék                                       21444    66.553861
# össz pontszám                                       21444   100.219269
# I. feleletválasztós kérdéssor                       20635    22.418173
# II. esszé: tartalom                                  5047    12.948286
# II. esszé:  kifejtés módja                           5047     4.228849
# III. összetett feladatok                             5047    28.152170
# írásbeli pontszám                                   20635    55.282966
# mérés és tételkifejtés: tartalmi helyesség           5058    35.715896
# mérés és tételkifejtés: felépítés, kifejtés          5058     4.014433
# szóbeli pontszám                                    20715    47.302872
# év                                                  21890  2013.364824
# egy téma kifejtése kísérlettel vagy méréssel: t...  15657    45.667369
# egy téma kifejtése kísérlettel vagy méréssel: f...  15657     4.162866
# II. összetett feladatok                             15588    28.829099
#
#                                                           std   min   25%  \
# vizsgázó évfolyama                                  34.817782     1    12
# érdemjegy                                            1.074826     1     3
# össz százalék                                       19.247675     0    54
# össz pontszám                                       28.865995     0    82
# I. feleletválasztós kérdéssor                        7.112939     2    18
# II. esszé: tartalom                                  3.860824     0    11
# II. esszé:  kifejtés módja                           1.023183     0     4
# III. összetett feladatok                            12.347646     0    19
# írásbeli pontszám                                   18.886694     8    41
# mérés és tételkifejtés: tartalmi helyesség           9.203527     0    31
# mérés és tételkifejtés: felépítés, kifejtés          1.096126     0     3
# szóbeli pontszám                                    12.863038     0    40
# év                                                   1.157214  2011  2012
# egy téma kifejtése kísérlettel vagy méréssel: t...  11.646716     0    40
# egy téma kifejtése kísérlettel vagy méréssel: f...   1.100549     0     3
# II. összetett feladatok                             12.855951     0    19
#
#                                                      50%   75%   max
# vizsgázó évfolyama                                    12    12  2014
# érdemjegy                                              4     5     5
# össz százalék                                         70    82   100
# össz pontszám                                        105   123   150
# I. feleletválasztós kérdéssor                         22    28    40
# II. esszé: tartalom                                   14    16    18
# II. esszé:  kifejtés módja                             5     5     5
# III. összetett feladatok                              29    39    47
# írásbeli pontszám                                     56    70   100
# mérés és tételkifejtés: tartalmi helyesség            38    43    90
# mérés és tételkifejtés: felépítés, kifejtés            4     5    10
# szóbeli pontszám                                      50    58   120
# év                                                  2013  2014  2015
# egy téma kifejtése kísérlettel vagy méréssel: t...    50    55   110
# egy téma kifejtése kísérlettel vagy méréssel: f...     5     5    10
# II. összetett feladatok                               29    40    50

# %% [markdown]
# A corr függvénnyel lekérhetjük a Pearson/Speaman/Kendall correlációs táblázatot.

# %%
df.corr(method="pearson")
# Out:
#                                                     vizsgázó évfolyama  \
# vizsgázó évfolyama                                            1.000000
# érdemjegy                                                     0.013730
# össz százalék                                                -0.000021
# össz pontszám                                                 0.000101
# I. feleletválasztós kérdéssor                                -0.006200
# II. esszé: tartalom                                          -0.012108
# II. esszé:  kifejtés módja                                   -0.016003
# III. összetett feladatok                                     -0.008011
# írásbeli pontszám                                             0.006674
# mérés és tételkifejtés: tartalmi helyesség                   -0.008256
# mérés és tételkifejtés: felépítés, kifejtés                   0.014697
# szóbeli pontszám                                             -0.012063
# év                                                            0.012776
# egy téma kifejtése kísérlettel vagy méréssel: t...            0.006201
# egy téma kifejtése kísérlettel vagy méréssel: f...           -0.000067
# II. összetett feladatok                                       0.050594
#
#                                                     érdemjegy  össz százalék  \
# vizsgázó évfolyama                                   0.013730      -0.000021
# érdemjegy                                            1.000000       0.907772
# össz százalék                                        0.907772       1.000000
# össz pontszám                                        0.906896       0.998582
# I. feleletválasztós kérdéssor                        0.507316       0.684114
# II. esszé: tartalom                                  0.560202       0.663993
# II. esszé:  kifejtés módja                           0.445160       0.500275
# III. összetett feladatok                             0.707938       0.891349
# írásbeli pontszám                                    0.846829       0.903683
# mérés és tételkifejtés: tartalmi helyesség           0.775403       0.805784
# mérés és tételkifejtés: felépítés, kifejtés          0.645829       0.686136
# szóbeli pontszám                                     0.632853       0.759383
# év                                                   0.049254       0.019835
# egy téma kifejtése kísérlettel vagy méréssel: t...   0.787951       0.810324
# egy téma kifejtése kísérlettel vagy méréssel: f...   0.666969       0.687220
# II. összetett feladatok                              0.842976       0.895515
#
#                                                     össz pontszám  \
# vizsgázó évfolyama                                       0.000101
# érdemjegy                                                0.906896
# össz százalék                                            0.998582
# össz pontszám                                            1.000000
# I. feleletválasztós kérdéssor                            0.684060
# II. esszé: tartalom                                      0.664042
# II. esszé:  kifejtés módja                               0.500438
# III. összetett feladatok                                 0.891243
# írásbeli pontszám                                        0.904050
# mérés és tételkifejtés: tartalmi helyesség               0.796333
# mérés és tételkifejtés: felépítés, kifejtés              0.676032
# szóbeli pontszám                                         0.748877
# év                                                       0.019255
# egy téma kifejtése kísérlettel vagy méréssel: t...       0.799206
# egy téma kifejtése kísérlettel vagy méréssel: f...       0.676825
# II. összetett feladatok                                  0.895725
#
#                                                     I. feleletválasztós kérdéssor  \
# vizsgázó évfolyama                                                      -0.006200
# érdemjegy                                                                0.507316
# össz százalék                                                            0.684114
# össz pontszám                                                            0.684060
# I. feleletválasztós kérdéssor                                            1.000000
# II. esszé: tartalom                                                      0.356895
# II. esszé:  kifejtés módja                                               0.256725
# III. összetett feladatok                                                 0.534321
# írásbeli pontszám                                                        0.652535
# mérés és tételkifejtés: tartalmi helyesség                               0.415918
# mérés és tételkifejtés: felépítés, kifejtés                              0.335439
# szóbeli pontszám                                                         0.474384
# év                                                                      -0.107093
# egy téma kifejtése kísérlettel vagy méréssel: t...                       0.400883
# egy téma kifejtése kísérlettel vagy méréssel: f...                       0.350101
# II. összetett feladatok                                                  0.639866
#
#                                                     II. esszé: tartalom  \
# vizsgázó évfolyama                                            -0.012108
# érdemjegy                                                      0.560202
# össz százalék                                                  0.663993
# össz pontszám                                                  0.664042
# I. feleletválasztós kérdéssor                                  0.356895
# II. esszé: tartalom                                            1.000000
# II. esszé:  kifejtés módja                                     0.646490
# III. összetett feladatok                                       0.518907
# írásbeli pontszám                                              0.686980
# mérés és tételkifejtés: tartalmi helyesség                     0.433555
# mérés és tételkifejtés: felépítés, kifejtés                    0.392058
# szóbeli pontszám                                               0.436247
# év                                                             0.131977
# egy téma kifejtése kísérlettel vagy méréssel: t...                  NaN
# egy téma kifejtése kísérlettel vagy méréssel: f...                  NaN
# II. összetett feladatok                                             NaN
#
#                                                     II. esszé:  kifejtés módja  \
# vizsgázó évfolyama                                                   -0.016003
# érdemjegy                                                             0.445160
# össz százalék                                                         0.500275
# össz pontszám                                                         0.500438
# I. feleletválasztós kérdéssor                                         0.256725
# II. esszé: tartalom                                                   0.646490
# II. esszé:  kifejtés módja                                            1.000000
# III. összetett feladatok                                              0.370415
# írásbeli pontszám                                                     0.506517
# mérés és tételkifejtés: tartalmi helyesség                            0.344682
# mérés és tételkifejtés: felépítés, kifejtés                           0.332567
# szóbeli pontszám                                                      0.349502
# év                                                                    0.076108
# egy téma kifejtése kísérlettel vagy méréssel: t...                         NaN
# egy téma kifejtése kísérlettel vagy méréssel: f...                         NaN
# II. összetett feladatok                                                    NaN
#
#                                                     III. összetett feladatok  \
# vizsgázó évfolyama                                                 -0.008011
# érdemjegy                                                           0.707938
# össz százalék                                                       0.891349
# össz pontszám                                                       0.891243
# I. feleletválasztós kérdéssor                                       0.534321
# II. esszé: tartalom                                                 0.518907
# II. esszé:  kifejtés módja                                          0.370415
# III. összetett feladatok                                            1.000000
# írásbeli pontszám                                                   0.941172
# mérés és tételkifejtés: tartalmi helyesség                          0.550949
# mérés és tételkifejtés: felépítés, kifejtés                         0.459826
# szóbeli pontszám                                                    0.550095
# év                                                                  0.081351
# egy téma kifejtése kísérlettel vagy méréssel: t...                       NaN
# egy téma kifejtése kísérlettel vagy méréssel: f...                       NaN
# II. összetett feladatok                                                  NaN
#
#                                                     írásbeli pontszám  \
# vizsgázó évfolyama                                           0.006674
# érdemjegy                                                    0.846829
# össz százalék                                                0.903683
# össz pontszám                                                0.904050
# I. feleletválasztós kérdéssor                                0.652535
# II. esszé: tartalom                                          0.686980
# II. esszé:  kifejtés módja                                   0.506517
# III. összetett feladatok                                     0.941172
# írásbeli pontszám                                            1.000000
# mérés és tételkifejtés: tartalmi helyesség                   0.591616
# mérés és tételkifejtés: felépítés, kifejtés                  0.499105
# szóbeli pontszám                                             0.420815
# év                                                           0.025150
# egy téma kifejtése kísérlettel vagy méréssel: t...           0.544409
# egy téma kifejtése kísérlettel vagy méréssel: f...           0.468870
# II. összetett feladatok                                      0.954703
#
#                                                     mérés és tételkifejtés: tartalmi helyesség  \
# vizsgázó évfolyama                                                                   -0.008256
# érdemjegy                                                                             0.775403
# össz százalék                                                                         0.805784
# össz pontszám                                                                         0.796333
# I. feleletválasztós kérdéssor                                                         0.415918
# II. esszé: tartalom                                                                   0.433555
# II. esszé:  kifejtés módja                                                            0.344682
# III. összetett feladatok                                                              0.550949
# írásbeli pontszám                                                                     0.591616
# mérés és tételkifejtés: tartalmi helyesség                                            1.000000
# mérés és tételkifejtés: felépítés, kifejtés                                           0.832555
# szóbeli pontszám                                                                      0.994463
# év                                                                                    0.009425
# egy téma kifejtése kísérlettel vagy méréssel: t...                                         NaN
# egy téma kifejtése kísérlettel vagy méréssel: f...                                         NaN
# II. összetett feladatok                                                                    NaN
#
#                                                     mérés és tételkifejtés: felépítés, kifejtés  \
# vizsgázó évfolyama                                                                     0.014697
# érdemjegy                                                                              0.645829
# össz százalék                                                                          0.686136
# össz pontszám                                                                          0.676032
# I. feleletválasztós kérdéssor                                                          0.335439
# II. esszé: tartalom                                                                    0.392058
# II. esszé:  kifejtés módja                                                             0.332567
# III. összetett feladatok                                                               0.459826
# írásbeli pontszám                                                                      0.499105
# mérés és tételkifejtés: tartalmi helyesség                                             0.832555
# mérés és tételkifejtés: felépítés, kifejtés                                            1.000000
# szóbeli pontszám                                                                       0.861251
# év                                                                                     0.007014
# egy téma kifejtése kísérlettel vagy méréssel: t...                                          NaN
# egy téma kifejtése kísérlettel vagy méréssel: f...                                          NaN
# II. összetett feladatok                                                                     NaN
#
#                                                     szóbeli pontszám  \
# vizsgázó évfolyama                                         -0.012063
# érdemjegy                                                   0.632853
# össz százalék                                               0.759383
# össz pontszám                                               0.748877
# I. feleletválasztós kérdéssor                               0.474384
# II. esszé: tartalom                                         0.436247
# II. esszé:  kifejtés módja                                  0.349502
# III. összetett feladatok                                    0.550095
# írásbeli pontszám                                           0.420815
# mérés és tételkifejtés: tartalmi helyesség                  0.994463
# mérés és tételkifejtés: felépítés, kifejtés                 0.861251
# szóbeli pontszám                                            1.000000
# év                                                         -0.022371
# egy téma kifejtése kísérlettel vagy méréssel: t...          0.995005
# egy téma kifejtése kísérlettel vagy méréssel: f...          0.836474
# II. összetett feladatok                                     0.552048
#
#                                                           év  \
# vizsgázó évfolyama                                  0.012776
# érdemjegy                                           0.049254
# össz százalék                                       0.019835
# össz pontszám                                       0.019255
# I. feleletválasztós kérdéssor                      -0.107093
# II. esszé: tartalom                                 0.131977
# II. esszé:  kifejtés módja                          0.076108
# III. összetett feladatok                            0.081351
# írásbeli pontszám                                   0.025150
# mérés és tételkifejtés: tartalmi helyesség          0.009425
# mérés és tételkifejtés: felépítés, kifejtés         0.007014
# szóbeli pontszám                                   -0.022371
# év                                                  1.000000
# egy téma kifejtése kísérlettel vagy méréssel: t...  0.002093
# egy téma kifejtése kísérlettel vagy méréssel: f...  0.011521
# II. összetett feladatok                             0.030493
#
#                                                     egy téma kifejtése kísérlettel vagy méréssel: tartalom  \
# vizsgázó évfolyama                                                                           0.006201
# érdemjegy                                                                                    0.787951
# össz százalék                                                                                0.810324
# össz pontszám                                                                                0.799206
# I. feleletválasztós kérdéssor                                                                0.400883
# II. esszé: tartalom                                                                               NaN
# II. esszé:  kifejtés módja                                                                        NaN
# III. összetett feladatok                                                                          NaN
# írásbeli pontszám                                                                            0.544409
# mérés és tételkifejtés: tartalmi helyesség                                                        NaN
# mérés és tételkifejtés: felépítés, kifejtés                                                       NaN
# szóbeli pontszám                                                                             0.995005
# év                                                                                           0.002093
# egy téma kifejtése kísérlettel vagy méréssel: t...                                           1.000000
# egy téma kifejtése kísérlettel vagy méréssel: f...                                           0.809229
# II. összetett feladatok                                                                      0.550518
#
#                                                     egy téma kifejtése kísérlettel vagy méréssel: felépítés, kifejtés  \
# vizsgázó évfolyama                                                                          -0.000067
# érdemjegy                                                                                    0.666969
# össz százalék                                                                                0.687220
# össz pontszám                                                                                0.676825
# I. feleletválasztós kérdéssor                                                                0.350101
# II. esszé: tartalom                                                                               NaN
# II. esszé:  kifejtés módja                                                                        NaN
# III. összetett feladatok                                                                          NaN
# írásbeli pontszám                                                                            0.468870
# mérés és tételkifejtés: tartalmi helyesség                                                        NaN
# mérés és tételkifejtés: felépítés, kifejtés                                                       NaN
# szóbeli pontszám                                                                             0.836474
# év                                                                                           0.011521
# egy téma kifejtése kísérlettel vagy méréssel: t...                                           0.809229
# egy téma kifejtése kísérlettel vagy méréssel: f...                                           1.000000
# II. összetett feladatok                                                                      0.471478
#
#                                                     II. összetett feladatok
# vizsgázó évfolyama                                                 0.050594
# érdemjegy                                                          0.842976
# össz százalék                                                      0.895515
# össz pontszám                                                      0.895725
# I. feleletválasztós kérdéssor                                      0.639866
# II. esszé: tartalom                                                     NaN
# II. esszé:  kifejtés módja                                              NaN
# III. összetett feladatok                                                NaN
# írásbeli pontszám                                                  0.954703
# mérés és tételkifejtés: tartalmi helyesség                              NaN
# mérés és tételkifejtés: felépítés, kifejtés                             NaN
# szóbeli pontszám                                                   0.552048
# év                                                                 0.030493
# egy téma kifejtése kísérlettel vagy méréssel: t...                 0.550518
# egy téma kifejtése kísérlettel vagy méréssel: f...                 0.471478
# II. összetett feladatok                                            1.000000

# %% [markdown]
# Ki is rajzolhatjuk könnyen.

# %%
c=df.corr(method="pearson")

imshow(c,interpolation="none",cmap='BrBG')
xticks(range(len(c.index)),c.index,rotation=90)
yticks(range(len(c.index)),c.index)
colorbar();

# %% [markdown]
# ## Ábrázolás

# %% [markdown]
# A `pandas` nagy erőssége, hogy a *DataFrame*-ekből nagyon rövid szintaxissal lehet egészen elfogadható ábrákat készíteni. Ehhez a `pandas` a `matplotlib` könyvtárat használja, melyet emiatt be is kell importálnunk.

# %% [markdown]
# Az ábra paramétereit (title, ylabel stb.) a `matplotlib`ben megszokott módon állíthatjuk be.
#
# Elsőként növeljük meg alapértelmezetten a tengelyfeliratokat:

# %%
rcParams["font.size"]=12

# %% [markdown]
# Eloszlások

# %%
pontok=df[['írásbeli pontszám',
         'III. összetett feladatok']]
pontok.head()
# Out:
#    írásbeli pontszám  III. összetett feladatok
# 0                NaN                       NaN
# 1                NaN                       NaN
# 2                 86                       NaN
# 3                 23                       NaN
# 4                 66                       NaN

# %%
pontok.hist(figsize=(8,4));

# %%
pontok.plot.hist(figsize=(9,6),alpha=0.5);

# %%
pontok.plot.box(figsize=(9,6));

# %% [markdown]
# Kovarianciák

# %%
pontok.plot.scatter(x='írásbeli pontszám',y= 'III. összetett feladatok');

# %%
pontok.plot.hexbin(x='írásbeli pontszám',y= 'III. összetett feladatok',gridsize=20);

# %% [markdown]
# Nézzük meg egyben néhány pontszám hisztogramját, és kovarianciáját

# %%
pd.scatter_matrix(pontok,figsize=(9,9));

# %% [markdown]
# #### Egyedi ábrák

# %% [markdown]
# Nézzük meg ábrán is az emelt szintű és a középszintű érettségizők számának időbeli alakulását.

# %%
toplot=df.groupby(['szint','év'])[['szint']].count()
toplot
# Out:
#             szint
# szint év
# E     2011     50
#       2012   1152
#       2013   1457
#       2014   1462
#       2015   1357
# K     2011    358
#       2012   4829
#       2013   4176
#       2014   3491
#       2015   3558

# %% [markdown]
# Használjuk az unstack függvényt hogy könnyen plottolhatóak legyenek az egyes csoportok.

# %%
toplot=toplot.unstack(level=0)
toplot
# Out:
#       szint
# szint     E     K
# év
# 2011     50   358
# 2012   1152  4829
# 2013   1457  4176
# 2014   1462  3491
# 2015   1357  3558

# %%
toplot.plot(kind="area", figsize=(9, 6))
ylabel("Érettségizok száma")
ylim(0,7000)
xticks(range(2011,2016),map(str,range(2011,2016)));

# %% [markdown]
# Megnézhetjük kördiagramon, hogy melyik iskolatípusból hányan érettségiztek közép- és emelt szinten 2011 és 2015 között. Ehhez két alábrát készítünk a múltkor tanultakhoz hasonlóan.
#
# Vajon mit csinált az `autopct` kulcsszó? Mi lehet a -?

# %%
t=df[(df["vizsgázó részvétele"]=="megjelent")].groupby(["szint","vizsgázó képzési típusa"])
t=t.size().unstack(level=1)
t.plot.pie(subplots=True,autopct="%.1f",figsize=(12,4));

# %% [markdown]
# ## Seaborn csomag

# %%
import seaborn as sns

# %% [markdown]
# Ez egy olyan csomag, amivel esztétikus plotokat készíthetünk kevés vesződséggel, leginkább statisztikai elemzésre.

# %% [markdown]
# Hisztogram és eloszlássűrűség-becslés.

# %%
sns.distplot(df['írásbeli pontszám'].dropna());

# %% [markdown]
# Csak kde (kernel density estimate).

# %%
sns.kdeplot(df['írásbeli pontszám']);

# %% [markdown]
# Kumulatív eloszlásfüggvény. ( De a becsült, nem az igazi! )

# %%
sns.kdeplot(df['írásbeli pontszám'].dropna(),cumulative=True);

# %% [markdown]
# Lehet több eloszlást egyben

# %%
pontok=df.loc[df['szint']=='K',['írásbeli pontszám',
           'szóbeli pontszám',
           'vizsgázó képzési típusa']]
pontok.head()
# Out:
#    írásbeli pontszám  szóbeli pontszám vizsgázó képzési típusa
# 0                NaN               NaN               gimnázium
# 1                NaN               NaN               gimnázium
# 2                 86                60               gimnázium
# 3                 23                38               gimnázium
# 4                 66                60               gimnázium

# %% [markdown]
# Egyesével kirajzolhatjuk a pontokat.

# %%
sns.stripplot(x='vizsgázó képzési típusa', y='írásbeli pontszám',
              data=pontok.dropna().iloc[:1000],jitter=True);

# %% [markdown]
# Dobozokat is rajzolhatunk.

# %%
sns.boxplot(x='vizsgázó képzési típusa', y='írásbeli pontszám',
              data=pontok);

# %% [markdown]
# Vagy az eloszlássűrűségeket egymás mellé.

# %%
sns.violinplot(x='vizsgázó képzési típusa', y='írásbeli pontszám',
              data=pontok);

# %% [markdown]
# Többdimenziós eloszlásokat is ábrázolhatunk.

# %%
x='írásbeli pontszám'
y='szóbeli pontszám'

# %% [markdown]
# Becsült eloszlássűrűséggel.

# %%
sns.jointplot(x=x, y=y, data=pontok, kind="kde");

# %% [markdown]
# Vagy hiszogramokkal is.

# %%
sns.jointplot(x=x, y=y, data=pontok,kind="hex", color="k");

# %% [markdown]
# A már látott párplot is megvan.

# %%
sns.pairplot(pontok.dropna());

# %% [markdown]
# Illeszhetünk és rajzolhatunk lineáris modellt.

# %%
sns.lmplot(x=y, y=x, data=pontok.dropna().iloc[:30,:]);

# %% [markdown]
# Kirajzolva még más dolgokat is.

# %%
sns.jointplot(x=y, y=x, data=pontok.dropna().iloc[:30,:],kind='reg');
