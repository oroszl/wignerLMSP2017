# %% [markdown]
# # Objektumok Pythonban
#
# Ebben a notebookban áttekintjük az objektumorientált programozás alapjait, illetve konkrét példákon keresztül a Python nyelv idevonatkozó szintaxisának sajátságait.
#
#
# - [Néhány turpisság](mutable_scope.ipynb)
#  - hivatkozások
#  - megváltoztathatóság
#  - láthatóság
#
# - [Osztályok](class.ipynb)
#  - a `class` struktúra
#  - példányosítás
#  - osztályváltozók és methodok
#  - öröklés
#  - operator overloading
